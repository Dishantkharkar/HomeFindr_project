# %% [markdown]
# # **Problem Statement**: Dataset Preprocessing for Real Estate Analysis
#
# * In the realm of real estate analysis, it is crucial to preprocess and refine raw data to extract meaningful insights. Your dataset provides information about various properties, including their attributes and characteristics.
# * The goal of this preprocessing task is to streamline the data, enhance its usability, and prepare it for further analysis.
# * The specific preprocessing steps involve creating a sector column based on address information, dropping unnecessary features, and ensuring data consistency.
#
# # **Description of Dataset:**
#
# The dataset contains information related to different properties available in a certain area. The dataset includes the following columns:
#
# * property_name: The name or identifier of the property.
# * property_type: The type or category of the property (e.g., apartment, villa, commercial space).
# * society: The name of the society or complex where the property is located.
# * price: The price of the property.
# * price_per_sqft: The price per square foot of the property.
# * area: The total area of the property in square feet.
# * areaWithType: The area along with the type (e.g., 2 BHK, 3 BHK + Study).
# * bedRoom: The number of bedrooms in the property.
# * bathroom: The number of bathrooms in the property.
# * balcony: The number of balconies in the property.
# * additionalRoom: Information about any additional rooms in the property.
# * address: The address of the property.
# * floorNum: The floor number of the property.
# * facing: The direction the property is facing (e.g., North, South, East, West).
# * agePossession: The age of the property or possession status.
# * nearbyLocations: Locations or landmarks near the property's vicinity.
# * description: A textual description of the property.
# * furnishDetails: Details about the furnishing status of the property.
# * features: Notable features or amenities of the property.
# * rating: A rating associated with the property's quality or desirability.
#
# # **Preprocessing Steps:**
#
# * **Sector Column Creation**: Extract the sector information from the address column and create a new column named sector. This column will help categorize properties based on their location.
#
# * **Feature Selection**: Identify features that are not relevant or contribute significantly to the analysis and decision-making process. Drop these features from the dataset to streamline the data and improve its quality.
#
# * **Data Consistency**: Check for any inconsistencies or missing values within the remaining features. Handle missing data appropriately by either imputing values or removing incomplete records.
#
# * **Data Format Optimization**: Convert any columns with non-standard formats (e.g., numeric values stored as text) to their appropriate data types.
#
# * **Data Normalization**: If necessary, normalize numeric columns to a common scale to avoid bias in analysis due to varying ranges.
#
# By completing these preprocessing steps, you will be able to transform the raw dataset into a cleaner, more organized, and more suitable format for your real estate analysis. This will ultimately assist you in making informed decisions and deriving valuable insights from the data.

# %% [markdown]
# # **Import Basic Libraries**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # **Import Dataset**

# %%
df = pd.read_csv('gurgaon_properties.csv')

# %% [markdown]
# # **Basic Checks**

# %%
df.head()
# Out:
#                                  property_name property_type  \
# 0              2 BHK Flat in Sector 93 Gurgaon          flat
# 1             2 BHK Flat in Sector 104 Gurgaon          flat
# 2             4 BHK Flat in Sector 104 Gurgaon          flat
# 3             3 BHK Flat in Sector 108 Gurgaon          flat
# 4  3 Bedroom House for sale in Nirvana Country         house
#
#                            society  price  price_per_sqft    area  \
# 0  signature global orchard avenue   0.40          7359.0   544.0
# 1                      zara aavaas   0.40          7029.0   569.0
# 2                      ats triumph   2.55         13076.0  1950.0
# 3           experion the heartsong   1.65          8237.0  2003.0
# 4           unitech deerwood chase   8.45        235376.0   359.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0                   Carpet area: 543.53 (50.5 sq.m.)        2         2
# 1               Super Built up area 569(52.86 sq.m.)        2         2
# 2  Super Built up area 3150(292.64 sq.m.)Carpet a...        4         4
# 3  Super Built up area 2003(186.08 sq.m.)Built Up...        3         4
# 4                         Plot area 359(33.35 sq.m.)        3         3
#
#   balcony           additionalRoom  \
# 0       2            not available
# 1       1            not available
# 2      3+             servant room
# 3       3               study room
# 4       2  study room,servant room
#
#                                        address  floorNum      facing  \
# 0          Sector 93 Gurgaon, Gurgaon, Haryana      11.0         NaN
# 1         Sector 104 Gurgaon, Gurgaon, Haryana      14.0         NaN
# 2   21st, Sector 104 Gurgaon, Gurgaon, Haryana      21.0        East
# 3         Sector 108 Gurgaon, Gurgaon, Haryana       3.0  North-West
# 4  Deerwood, Nirvana Country, Gurgaon, Haryana       2.0  North-East
#
#       agePossession                                    nearbyLocations  \
# 0   0 to 1 Year Old  ['JMS Crosswalk Mall', 'Reliance Trends Newtow...
# 1   1 to 5 Year Old  ['Ardee Mall', 'Northern Peripheral Road', 'Mp...
# 2   1 to 5 Year Old  ['IFFCO Chowk Metro Station', 'The Esplanade M...
# 3  5 to 10 Year Old  ['Galleria 108 Mall', 'Dwarka Expressway', 'Ce...
# 4      10+ Year Old  ['Sector 55-56 Metro Station', 'Raheja Mall', ...
#
#                                          description  \
# 0  Situated in sector-93 gurgaon, gurgaon, signat...
# 1  Residential apartment for sell.Located in sect...
# 2  Looking for a 4 bhk property for sale in gurga...
# 3  Experion, one of the most reputed real estate ...
# 4  Brokers pls excuse....Independent villa availa...
#
#                                       furnishDetails  \
# 0  ['1 Fan', '1 Exhaust Fan', '1 Geyser', '5 Ligh...
# 1  ['2 Fan', '2 Light', '2 Wardrobe', 'No AC', 'N...
# 2  ['6 Fan', '18 Light', '4 AC', 'No Bed', 'No Ch...
# 3  ['6 Fan', '6 Light', '4 AC', '1 Modular Kitche...
# 4  ['5 Fan', '1 Exhaust Fan', '6 Geyser', '1 Stov...
#
#                                             features  \
# 0  ['Security / Fire Alarm', 'Lift(s)', 'Maintena...
# 1  ['Intercom Facility', 'Lift(s)', 'Swimming Poo...
# 2  ['Water purifier', 'Centrally Air Conditioned'...
# 3  ['Security / Fire Alarm', 'Power Back-up', 'In...
# 4  ['Feng Shui / Vaastu Compliant', 'Private Gard...
#
#                                               rating
# 0  ['Green Area4 out of 5', 'Construction4 out of...
# 1  ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 2  ['Green Area4 out of 5', 'Construction5 out of...
# 3  ['Green Area5 out of 5', 'Construction4 out of...
# 4  ['Environment5 out of 5', 'Lifestyle5 out of 5...

# %%
# shape
df.shape
# Out:
# (3974, 20)

# %% [markdown]
# **Drop Duplicated**

# %%
df.duplicated().sum()
# Out:
# 13

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (3961, 20)

# %%
# info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3961 entries, 0 to 3973
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    3961 non-null   object
#  1   property_type    3961 non-null   object
#  2   society          3960 non-null   object
#  3   price            3941 non-null   float64
#  4   price_per_sqft   3941 non-null   float64
#  5   area             3941 non-null   float64
#  6   areaWithType     3961 non-null   object
#  7   bedRoom          3961 non-null   int64
#  8   bathroom         3961 non-null   int64
#  9   balcony          3961 non-null   object
#  10  additionalRoom   3961 non-null   object
#  11  address          3950 non-null   object
#  12  floorNum         3940 non-null   float64
#  13  facing           2784 non-null   object
#  14  agePossession    3960 non-null   object
#  15  nearbyLocations  3754 non-null   object
#  16  description      3961 non-null   object
#  17  furnishDetails   2929 non-null   object
#  18  features         3252 non-null   object
#  19  rating           3511 non-null   object
# dtypes: float64(4), int64(2), object(14)
# memory usage: 649.9+ KB

# %%
# Check null values
df.isnull().sum()
# Out:
# property_name         0
# property_type         0
# society               1
# price                20
# price_per_sqft       20
# area                 20
# areaWithType          0
# bedRoom               0
# bathroom              0
# balcony               0
# additionalRoom        0
# address              11
# floorNum             21
# facing             1177
# agePossession         1
# nearbyLocations     207
# description           0
# furnishDetails     1032
# features            709
# rating              450
# dtype: int64

# %% [markdown]
# # **Data Preprocesssing**

# %%
df.head()
# Out:
#                                  property_name property_type  \
# 0              2 BHK Flat in Sector 93 Gurgaon          flat
# 1             2 BHK Flat in Sector 104 Gurgaon          flat
# 2             4 BHK Flat in Sector 104 Gurgaon          flat
# 3             3 BHK Flat in Sector 108 Gurgaon          flat
# 4  3 Bedroom House for sale in Nirvana Country         house
#
#                            society  price  price_per_sqft    area  \
# 0  signature global orchard avenue   0.40          7359.0   544.0
# 1                      zara aavaas   0.40          7029.0   569.0
# 2                      ats triumph   2.55         13076.0  1950.0
# 3           experion the heartsong   1.65          8237.0  2003.0
# 4           unitech deerwood chase   8.45        235376.0   359.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0                   Carpet area: 543.53 (50.5 sq.m.)        2         2
# 1               Super Built up area 569(52.86 sq.m.)        2         2
# 2  Super Built up area 3150(292.64 sq.m.)Carpet a...        4         4
# 3  Super Built up area 2003(186.08 sq.m.)Built Up...        3         4
# 4                         Plot area 359(33.35 sq.m.)        3         3
#
#   balcony           additionalRoom  \
# 0       2            not available
# 1       1            not available
# 2      3+             servant room
# 3       3               study room
# 4       2  study room,servant room
#
#                                        address  floorNum      facing  \
# 0          Sector 93 Gurgaon, Gurgaon, Haryana      11.0         NaN
# 1         Sector 104 Gurgaon, Gurgaon, Haryana      14.0         NaN
# 2   21st, Sector 104 Gurgaon, Gurgaon, Haryana      21.0        East
# 3         Sector 108 Gurgaon, Gurgaon, Haryana       3.0  North-West
# 4  Deerwood, Nirvana Country, Gurgaon, Haryana       2.0  North-East
#
#       agePossession                                    nearbyLocations  \
# 0   0 to 1 Year Old  ['JMS Crosswalk Mall', 'Reliance Trends Newtow...
# 1   1 to 5 Year Old  ['Ardee Mall', 'Northern Peripheral Road', 'Mp...
# 2   1 to 5 Year Old  ['IFFCO Chowk Metro Station', 'The Esplanade M...
# 3  5 to 10 Year Old  ['Galleria 108 Mall', 'Dwarka Expressway', 'Ce...
# 4      10+ Year Old  ['Sector 55-56 Metro Station', 'Raheja Mall', ...
#
#                                          description  \
# 0  Situated in sector-93 gurgaon, gurgaon, signat...
# 1  Residential apartment for sell.Located in sect...
# 2  Looking for a 4 bhk property for sale in gurga...
# 3  Experion, one of the most reputed real estate ...
# 4  Brokers pls excuse....Independent villa availa...
#
#                                       furnishDetails  \
# 0  ['1 Fan', '1 Exhaust Fan', '1 Geyser', '5 Ligh...
# 1  ['2 Fan', '2 Light', '2 Wardrobe', 'No AC', 'N...
# 2  ['6 Fan', '18 Light', '4 AC', 'No Bed', 'No Ch...
# 3  ['6 Fan', '6 Light', '4 AC', '1 Modular Kitche...
# 4  ['5 Fan', '1 Exhaust Fan', '6 Geyser', '1 Stov...
#
#                                             features  \
# 0  ['Security / Fire Alarm', 'Lift(s)', 'Maintena...
# 1  ['Intercom Facility', 'Lift(s)', 'Swimming Poo...
# 2  ['Water purifier', 'Centrally Air Conditioned'...
# 3  ['Security / Fire Alarm', 'Power Back-up', 'In...
# 4  ['Feng Shui / Vaastu Compliant', 'Private Gard...
#
#                                               rating
# 0  ['Green Area4 out of 5', 'Construction4 out of...
# 1  ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 2  ['Green Area4 out of 5', 'Construction5 out of...
# 3  ['Green Area5 out of 5', 'Construction4 out of...
# 4  ['Environment5 out of 5', 'Lifestyle5 out of 5...

# %%
# insert one sector columns and sector information came from property name column because sector very information in metro cities like Gurugaon
df.insert(loc=3,column='sector',value=df['property_name'].str.split('in').str.get(1).str.replace('Gurgaon','').str.strip())

# %%
df.head()
# Out:
#                                  property_name property_type  \
# 0              2 BHK Flat in Sector 93 Gurgaon          flat
# 1             2 BHK Flat in Sector 104 Gurgaon          flat
# 2             4 BHK Flat in Sector 104 Gurgaon          flat
# 3             3 BHK Flat in Sector 108 Gurgaon          flat
# 4  3 Bedroom House for sale in Nirvana Country         house
#
#                            society           sector  price  price_per_sqft  \
# 0  signature global orchard avenue        Sector 93   0.40          7359.0
# 1                      zara aavaas       Sector 104   0.40          7029.0
# 2                      ats triumph       Sector 104   2.55         13076.0
# 3           experion the heartsong       Sector 108   1.65          8237.0
# 4           unitech deerwood chase  Nirvana Country   8.45        235376.0
#
#      area                                       areaWithType  bedRoom  \
# 0   544.0                   Carpet area: 543.53 (50.5 sq.m.)        2
# 1   569.0               Super Built up area 569(52.86 sq.m.)        2
# 2  1950.0  Super Built up area 3150(292.64 sq.m.)Carpet a...        4
# 3  2003.0  Super Built up area 2003(186.08 sq.m.)Built Up...        3
# 4   359.0                         Plot area 359(33.35 sq.m.)        3
#
#    bathroom  ...           additionalRoom  \
# 0         2  ...            not available
# 1         2  ...            not available
# 2         4  ...             servant room
# 3         4  ...               study room
# 4         3  ...  study room,servant room
#
#                                        address floorNum      facing  \
# 0          Sector 93 Gurgaon, Gurgaon, Haryana     11.0         NaN
# 1         Sector 104 Gurgaon, Gurgaon, Haryana     14.0         NaN
# 2   21st, Sector 104 Gurgaon, Gurgaon, Haryana     21.0        East
# 3         Sector 108 Gurgaon, Gurgaon, Haryana      3.0  North-West
# 4  Deerwood, Nirvana Country, Gurgaon, Haryana      2.0  North-East
#
#       agePossession                                    nearbyLocations  \
# 0   0 to 1 Year Old  ['JMS Crosswalk Mall', 'Reliance Trends Newtow...
# 1   1 to 5 Year Old  ['Ardee Mall', 'Northern Peripheral Road', 'Mp...
# 2   1 to 5 Year Old  ['IFFCO Chowk Metro Station', 'The Esplanade M...
# 3  5 to 10 Year Old  ['Galleria 108 Mall', 'Dwarka Expressway', 'Ce...
# 4      10+ Year Old  ['Sector 55-56 Metro Station', 'Raheja Mall', ...
#
#                                          description  \
# 0  Situated in sector-93 gurgaon, gurgaon, signat...
# 1  Residential apartment for sell.Located in sect...
# 2  Looking for a 4 bhk property for sale in gurga...
# 3  Experion, one of the most reputed real estate ...
# 4  Brokers pls excuse....Independent villa availa...
#
#                                       furnishDetails  \
# 0  ['1 Fan', '1 Exhaust Fan', '1 Geyser', '5 Ligh...
# 1  ['2 Fan', '2 Light', '2 Wardrobe', 'No AC', 'N...
# 2  ['6 Fan', '18 Light', '4 AC', 'No Bed', 'No Ch...
# 3  ['6 Fan', '6 Light', '4 AC', '1 Modular Kitche...
# 4  ['5 Fan', '1 Exhaust Fan', '6 Geyser', '1 Stov...
#
#                                             features  \
# 0  ['Security / Fire Alarm', 'Lift(s)', 'Maintena...
# 1  ['Intercom Facility', 'Lift(s)', 'Swimming Poo...
# 2  ['Water purifier', 'Centrally Air Conditioned'...
# 3  ['Security / Fire Alarm', 'Power Back-up', 'In...
# 4  ['Feng Shui / Vaastu Compliant', 'Private Gard...
#
#                                               rating
# 0  ['Green Area4 out of 5', 'Construction4 out of...
# 1  ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 2  ['Green Area4 out of 5', 'Construction5 out of...
# 3  ['Green Area5 out of 5', 'Construction4 out of...
# 4  ['Environment5 out of 5', 'Lifestyle5 out of 5...
#
# [5 rows x 21 columns]

# %%
df['sector']=df['sector'].str.lower() # for lower case

# %%
df.head()
# Out:
#                                  property_name property_type  \
# 0              2 BHK Flat in Sector 93 Gurgaon          flat
# 1             2 BHK Flat in Sector 104 Gurgaon          flat
# 2             4 BHK Flat in Sector 104 Gurgaon          flat
# 3             3 BHK Flat in Sector 108 Gurgaon          flat
# 4  3 Bedroom House for sale in Nirvana Country         house
#
#                            society           sector  price  price_per_sqft  \
# 0  signature global orchard avenue        sector 93   0.40          7359.0
# 1                      zara aavaas       sector 104   0.40          7029.0
# 2                      ats triumph       sector 104   2.55         13076.0
# 3           experion the heartsong       sector 108   1.65          8237.0
# 4           unitech deerwood chase  nirvana country   8.45        235376.0
#
#      area                                       areaWithType  bedRoom  \
# 0   544.0                   Carpet area: 543.53 (50.5 sq.m.)        2
# 1   569.0               Super Built up area 569(52.86 sq.m.)        2
# 2  1950.0  Super Built up area 3150(292.64 sq.m.)Carpet a...        4
# 3  2003.0  Super Built up area 2003(186.08 sq.m.)Built Up...        3
# 4   359.0                         Plot area 359(33.35 sq.m.)        3
#
#    bathroom  ...           additionalRoom  \
# 0         2  ...            not available
# 1         2  ...            not available
# 2         4  ...             servant room
# 3         4  ...               study room
# 4         3  ...  study room,servant room
#
#                                        address floorNum      facing  \
# 0          Sector 93 Gurgaon, Gurgaon, Haryana     11.0         NaN
# 1         Sector 104 Gurgaon, Gurgaon, Haryana     14.0         NaN
# 2   21st, Sector 104 Gurgaon, Gurgaon, Haryana     21.0        East
# 3         Sector 108 Gurgaon, Gurgaon, Haryana      3.0  North-West
# 4  Deerwood, Nirvana Country, Gurgaon, Haryana      2.0  North-East
#
#       agePossession                                    nearbyLocations  \
# 0   0 to 1 Year Old  ['JMS Crosswalk Mall', 'Reliance Trends Newtow...
# 1   1 to 5 Year Old  ['Ardee Mall', 'Northern Peripheral Road', 'Mp...
# 2   1 to 5 Year Old  ['IFFCO Chowk Metro Station', 'The Esplanade M...
# 3  5 to 10 Year Old  ['Galleria 108 Mall', 'Dwarka Expressway', 'Ce...
# 4      10+ Year Old  ['Sector 55-56 Metro Station', 'Raheja Mall', ...
#
#                                          description  \
# 0  Situated in sector-93 gurgaon, gurgaon, signat...
# 1  Residential apartment for sell.Located in sect...
# 2  Looking for a 4 bhk property for sale in gurga...
# 3  Experion, one of the most reputed real estate ...
# 4  Brokers pls excuse....Independent villa availa...
#
#                                       furnishDetails  \
# 0  ['1 Fan', '1 Exhaust Fan', '1 Geyser', '5 Ligh...
# 1  ['2 Fan', '2 Light', '2 Wardrobe', 'No AC', 'N...
# 2  ['6 Fan', '18 Light', '4 AC', 'No Bed', 'No Ch...
# 3  ['6 Fan', '6 Light', '4 AC', '1 Modular Kitche...
# 4  ['5 Fan', '1 Exhaust Fan', '6 Geyser', '1 Stov...
#
#                                             features  \
# 0  ['Security / Fire Alarm', 'Lift(s)', 'Maintena...
# 1  ['Intercom Facility', 'Lift(s)', 'Swimming Poo...
# 2  ['Water purifier', 'Centrally Air Conditioned'...
# 3  ['Security / Fire Alarm', 'Power Back-up', 'In...
# 4  ['Feng Shui / Vaastu Compliant', 'Private Gard...
#
#                                               rating
# 0  ['Green Area4 out of 5', 'Construction4 out of...
# 1  ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 2  ['Green Area4 out of 5', 'Construction5 out of...
# 3  ['Green Area5 out of 5', 'Construction4 out of...
# 4  ['Environment5 out of 5', 'Lifestyle5 out of 5...
#
# [5 rows x 21 columns]

# %%
df['sector'].value_counts()
# Out:
# sohna                 163
# sector 102            113
# sector 85             110
# sector 92             104
# sector 69              94
#                      ...
# near euro               1
# ram nagar               1
# kheri                   1
# shivji park colony      1
# vir nagar               1
# Name: sector, Length: 301, dtype: int64

# %% [markdown]
# * Here there many Colony present in sector columns but we want specific sector information so we collect data from internet which colony placed in which sector
# * and then replace it with sector

# %%
df['sector'] = df['sector'].str.replace('dharam colony','sector 12')
df['sector'] = df['sector'].str.replace('krishna colony','sector 7')
df['sector'] = df['sector'].str.replace('suncity','sector 54')
df['sector'] = df['sector'].str.replace('prem nagar','sector 13')
df['sector'] = df['sector'].str.replace('mg road','sector 28')
df['sector'] = df['sector'].str.replace('gandhi nagar','sector 28')
df['sector'] = df['sector'].str.replace('laxmi garden','sector 11')
df['sector'] = df['sector'].str.replace('shakti nagar','sector 11')

# %%
df['sector'] = df['sector'].str.replace('baldev nagar','sector 7')
df['sector'] = df['sector'].str.replace('shivpuri','sector 7')
df['sector'] = df['sector'].str.replace('garhi harsaru','sector 17')
df['sector'] = df['sector'].str.replace('imt manesar','manesar')
df['sector'] = df['sector'].str.replace('adarsh nagar','sector 12')
df['sector'] = df['sector'].str.replace('shivaji nagar','sector 11')
df['sector'] = df['sector'].str.replace('bhim nagar','sector 6')
df['sector'] = df['sector'].str.replace('madanpuri','sector 7')

# %%
df['sector'] = df['sector'].str.replace('saraswati vihar','sector 28')
df['sector'] = df['sector'].str.replace('arjun nagar','sector 8')
df['sector'] = df['sector'].str.replace('ravi nagar','sector 9')
df['sector'] = df['sector'].str.replace('vishnu garden','sector 105')
df['sector'] = df['sector'].str.replace('bhondsi','sector 11')
df['sector'] = df['sector'].str.replace('surya vihar','sector 21')
df['sector'] = df['sector'].str.replace('devilal colony','sector 9')
df['sector'] = df['sector'].str.replace('valley view estate','gwal pahari')

# %%
df['sector'] = df['sector'].str.replace('mehrauli  road','sector 14')
df['sector'] = df['sector'].str.replace('jyoti park','sector 7')
df['sector'] = df['sector'].str.replace('ansal plaza','sector 23')
df['sector'] = df['sector'].str.replace('dayanand colony','sector 6')
df['sector'] = df['sector'].str.replace('sushant lok phase 2','sector 55')
df['sector'] = df['sector'].str.replace('chakkarpur','sector 28')
df['sector'] = df['sector'].str.replace('greenwood city','sector 45')
df['sector'] = df['sector'].str.replace('subhash nagar','sector 12')

# %%
df['sector'] = df['sector'].str.replace('sohna road road','sohna road')
df['sector'] = df['sector'].str.replace('malibu town','sector 47')
df['sector'] = df['sector'].str.replace('surat nagar 1','sector 104')
df['sector'] = df['sector'].str.replace('new colony','sector 7')
df['sector'] = df['sector'].str.replace('mianwali colony','sector 12')
df['sector'] = df['sector'].str.replace('jacobpura','sector 12')
df['sector'] = df['sector'].str.replace('rajiv nagar','sector 13')
df['sector'] = df['sector'].str.replace('ashok vihar','sector 3')

# %%
df['sector'] = df['sector'].str.replace('dlf phase 1','sector 26')
df['sector'] = df['sector'].str.replace('nirvana country','sector 50')
df['sector'] = df['sector'].str.replace('palam vihar','sector 2')
df['sector'] = df['sector'].str.replace('dlf phase 2','sector 25')
df['sector'] = df['sector'].str.replace('sushant lok phase 1','sector 43')
df['sector'] = df['sector'].str.replace('laxman vihar','sector 4')
df['sector'] = df['sector'].str.replace('dlf phase 4','sector 28')
df['sector'] = df['sector'].str.replace('dlf phase 3','sector 24')

# %%
df['sector'] = df['sector'].str.replace('sushant lok phase 3','sector 57')
df['sector'] = df['sector'].str.replace('dlf phase 5','sector 43')
df['sector'] = df['sector'].str.replace('rajendra park','sector 105')
df['sector'] = df['sector'].str.replace('uppals southend','sector 49')
df['sector'] = df['sector'].str.replace('sohna','sohna road')
df['sector'] = df['sector'].str.replace('ashok vihar phase 3 extension','sector 5')
df['sector'] = df['sector'].str.replace('south city 1','sector 41')
df['sector'] = df['sector'].str.replace('ashok vihar phase 2','sector 5')

# %%
a = df['sector'].value_counts()[df['sector'].value_counts() >= 3]
df = df[df['sector'].isin(a.index)]

# %%
df['sector'].value_counts()
# Out:
# sohna road           163
# sector 102           113
# sector 85            110
# sector 92            104
# sector 69             94
#                     ...
# sector 110 a           3
# a block sector 43      3
# sector 17a             3
# b block sector 43      3
# maruti kunj            3
# Name: sector, Length: 131, dtype: int64

# %%
df['sector'] = df['sector'].str.replace('sector 95a','sector 95')
df['sector'] = df['sector'].str.replace('sector 23a','sector 23')
df['sector'] = df['sector'].str.replace('sector 12a','sector 12')
df['sector'] = df['sector'].str.replace('sector 3a','sector 3')
df['sector'] = df['sector'].str.replace('sector 110 a','sector 110')
df['sector'] = df['sector'].str.replace('patel nagar','sector 15')
df['sector'] = df['sector'].str.replace('a block sector 43','sector 43')
df['sector'] = df['sector'].str.replace('maruti kunj','sector 12')
df['sector'] = df['sector'].str.replace('b block sector 43','sector 43')

# %%
df['sector'] = df['sector'].str.replace('sector-33 sohna road','sector 33')
df['sector'] = df['sector'].str.replace('sector 1 manesar','manesar')
df['sector'] = df['sector'].str.replace('sector 4 phase 2','sector 4')
df['sector'] = df['sector'].str.replace('sector 1a manesar','manesar')
df['sector'] = df['sector'].str.replace('c block sector 43','sector 43')
df['sector'] = df['sector'].str.replace('sector 89 a','sector 89')
df['sector'] = df['sector'].str.replace('sector 2 extension','sector 2')
df['sector'] = df['sector'].str.replace('sector 36 sohna road','sector 36')

# %%
df[df['sector'] == 'new']
# Out:
#                   property_name property_type                       society  \
# 597   2 BHK Flat in New Gurgaon          flat  takshila heights sector 37 c
# 1603  2 BHK Flat in New Gurgaon          flat                   green court
# 3709  4 BHK Flat in New Gurgaon          flat                    sare homes
# 3778  4 BHK Flat in New Gurgaon          flat                        dlf 76
#
#      sector  price  price_per_sqft    area  \
# 597     new   0.67          5583.0  1200.0
# 1603    new   0.38          5507.0   690.0
# 3709    new   0.85          4786.0  1776.0
# 3778    new   4.00         11428.0  3500.0
#
#                                 areaWithType  bedRoom  bathroom  ...  \
# 597   Super Built up area 1200(111.48 sq.m.)        2         2  ...
# 1603           Carpet area: 690 (64.1 sq.m.)        2         2  ...
# 3709     Super Built up area 1776(165 sq.m.)        4         4  ...
# 3778        Carpet area: 3500 (325.16 sq.m.)        4         4  ...
#
#                additionalRoom                        address floorNum  facing  \
# 597             not available  New Gurgaon, Gurgaon, Haryana      3.0     NaN
# 1603            not available  New Gurgaon, Gurgaon, Haryana      7.0     NaN
# 3709            not available  New Gurgaon, Gurgaon, Haryana      3.0     NaN
# 3778  study room,servant room  New Gurgaon, Gurgaon, Haryana      4.0     NaN
#
#            agePossession                                    nearbyLocations  \
# 597      1 to 5 Year Old  ['Shri Balaji Hospital and Trauma Center', 'S....
# 1603  Under Construction  ['Ing bank ATM', 'Dcb bank ATM', 'Indus ind ba...
# 3709    5 to 10 Year Old  ['Columbia Asia Hospital', 'Apex Multi Special...
# 3778              Jun-27  ['Shri Balaji Hospital and Trauma Center', 'S....
#
#                                             description  \
# 597   Check out this 2 bhk apartment for sale in tak...
# 1603  We are the proud owners of this 2 bhk apartmen...
# 3709  Located in the popular residential address of ...
# 3778  This lovely 4 bhk apartment/flat in new gurgao...
#
#                                          furnishDetails  \
# 597                                                  []
# 1603                                                 []
# 3709                                                 []
# 3778  ['6 Wardrobe', '1 Fridge', '8 Fan', '1 Exhaust...
#
#                                                features rating
# 597   ['Lift(s)', 'Swimming Pool', 'Visitor Parking'...    NaN
# 1603  ['Intercom Facility', 'Lift(s)', 'Maintenance ...    NaN
# 3709                                                NaN    NaN
# 3778  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...    NaN
#
# [4 rows x 21 columns]

# %%
df.loc[597,'sector'] = 'sector 37'
df.loc[1603,'sector'] = 'sector 90'
df.loc[3709,'sector'] = 'sector 92'
df.loc[3778,'sector'] = 'sector 76'

# %%
df[df['sector'] == 'new sector 2']
# Out:
#                                     property_name property_type  \
# 8     2 Bedroom House for sale in New Palam Vihar         house
# 1815                2 BHK Flat in New Palam Vihar          flat
# 2582                2 BHK Flat in New Palam Vihar          flat
# 2946                2 BHK Flat in New Palam Vihar          flat
# 3239  3 Bedroom House for sale in New Palam Vihar         house
#
#                   society        sector  price  price_per_sqft    area  \
# 8                 my home  new sector 2   0.34         12592.0   270.0
# 1815  ompee k s residency  new sector 2   1.60         26936.0   594.0
# 2582              my home  new sector 2   0.22          4400.0   500.0
# 2946              my home  new sector 2   0.28          3166.0   884.0
# 3239          independent  new sector 2   1.00          8796.0  1137.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 8                            Plot area 270(25.08 sq.m.)        2         2
# 1815                      Carpet area: 66 (55.18 sq.m.)        2         2
# 2582                     Carpet area: 500 (46.45 sq.m.)        2         2
# 2946                     Carpet area: 900 (83.61 sq.m.)        2         1
# 3239  Plot area 120(100.34 sq.m.)Built Up area: 120 ...        3         2
#
#       ... additionalRoom                                            address  \
# 8     ...  not available         Ez-19 A, New Palam Vihar, Gurgaon, Haryana
# 1815  ...  not available                  New Palam Vihar, Gurgaon, Haryana
# 2582  ...  not available                  New Palam Vihar, Gurgaon, Haryana
# 2946  ...         others         F 150/b, New Palam Vihar, Gurgaon, Haryana
# 3239  ...     pooja room  Q-148, New Palam Vihar, Phase-2, Near Royal Oa...
#
#      floorNum  facing     agePossession  \
# 8         3.0    West  5 to 10 Year Old
# 1815      1.0     NaN   1 to 5 Year Old
# 2582      1.0     NaN   0 to 1 Year Old
# 2946      2.0     NaN   1 to 5 Year Old
# 3239      1.0   North      10+ Year Old
#
#                                         nearbyLocations  \
# 8     ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 1815  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 2582  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 2946  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 3239  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
#
#                                             description  \
# 8     There are availability of various facilities l...
# 1815  We are the proud owners of this 2 bhk apartmen...
# 2582  Cctv surveillance are provided here. There is ...
# 2946  2 bhk room with wooden coverd ,1 drawing room,...
# 3239  Ground and first floor, Ground floor: Ground f...
#
#                                          furnishDetails  \
# 8     ['1 Wardrobe', '3 Fan', '6 Light', 'No AC', 'N...
# 1815                                                NaN
# 2582  ['3 Fan', '1 Exhaust Fan', '15 Light', '1 Modu...
# 2946  ['3 Wardrobe', '5 Light', '1 Chimney', '1 Modu...
# 3239                                                NaN
#
#                                           features  \
# 8     ['Water Storage', 'Park', 'Visitor Parking']
# 1815                                           NaN
# 2582                                           NaN
# 2946                     ['Water Storage', 'Park']
# 3239                                           NaN
#
#                                                  rating
# 8     ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 1815  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 2582  ['Safety4 out of 5', 'Lifestyle4 out of 5', 'E...
# 2946  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 3239  ['Environment4 out of 5', 'Lifestyle4 out of 5...
#
# [5 rows x 21 columns]

# %%
df.loc[[8,1815,2582,2946,3239],'sector'] = 'sector 110'

# %%
df.shape
# Out:
# (3803, 21)

# %%
df.sample(5)
# Out:
#                          property_name property_type  \
# 2567  2 BHK Flat in Sector 113 Gurgaon          flat
# 850    3 BHK Flat in Sector 47 Gurgaon          flat
# 3406   3 BHK Flat in Sector 92 Gurgaon          flat
# 577   3 BHK Flat in Sector 102 Gurgaon          flat
# 1167   3 BHK Flat in Sector 79 Gurgaon          flat
#
#                        society      sector  price  price_per_sqft    area  \
# 2567   la vida by tata housing  sector 113   1.55         11654.0  1330.0
# 850   unitech uniworld gardens   sector 47   2.40         11505.0  2086.0
# 3406                sare homes   sector 92   0.71          5354.0  1326.0
# 577        adani oyster greens  sector 102   1.90         10058.0  1889.0
# 1167        mapsko mount ville   sector 79   1.28          8557.0  1496.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 2567  Super Built up area 1330(123.56 sq.m.)Built Up...        2         2
# 850               Super Built up area 2086(193.8 sq.m.)        3         3
# 3406                   Carpet area: 1326 (123.19 sq.m.)        3         3
# 577                    Carpet area: 1889 (175.49 sq.m.)        3         3
# 1167  Super Built up area 1490(138.43 sq.m.)Carpet a...        3         3
#
#       ...                    additionalRoom  \
# 2567  ...                     not available
# 850   ...                      servant room
# 3406  ...                        pooja room
# 577   ...  pooja room,study room,store room
# 1167  ...                        study room
#
#                                              address floorNum      facing  \
# 2567           Sector 113 Gurgaon , Gurgaon, Haryana      2.0  North-East
# 850              Sector 47 Gurgaon, Gurgaon, Haryana     10.0         NaN
# 3406       7002, Sector 92 Gurgaon, Gurgaon, Haryana      2.0  North-West
# 577       1456, Sector 102 Gurgaon, Gurgaon, Haryana      9.0  North-East
# 1167  Sector-79, Sector 79 Gurgaon, Gurgaon, Haryana     16.0       South
#
#          agePossession                                    nearbyLocations  \
# 2567   0 to 1 Year Old  ['Dwarka Sector 21', 'Pacific D21 Mall', 'Bajg...
# 850   5 to 10 Year Old  ['Rajiv Chowk Mosque', 'Standard chartered ATM...
# 3406   1 to 5 Year Old  ['Yadav Clinic', 'Bangali Clinic', 'Dr. J. S. ...
# 577    1 to 5 Year Old  ['MSK bedding products', 'INOX Gurgaon Dreamz ...
# 1167   1 to 5 Year Old  ['Huda Metro Station (Gurugram)', 'Sapphire 83...
#
#                                             description  \
# 2567  Situated in sector 113 gurgaon , la vida by ta...
# 850   3bhk + sq, 2086 sq feet\nSemi-Furnished \nNewl...
# 3406  Sare homes is one of gurgaon's most sought aft...
# 577   Looking for a 3 bhk property for sale in gurga...
# 1167  1490 sqft 3 bhk 3 bathroom semi furnished apar...
#
#                                          furnishDetails  \
# 2567  ['2 Light', 'No AC', 'No Bed', 'No Chimney', '...
# 850   ['3 Wardrobe', '6 Fan', '3 Geyser', '15 Light'...
# 3406                                                NaN
# 577   ['8 Fan', '7 Light', '1 Modular Kitchen', '1 C...
# 1167  ['3 Wardrobe', '1 Fan', '1 Exhaust Fan', '1 Li...
#
#                                                features  \
# 2567  ['Centrally Air Conditioned', 'Water purifier'...
# 850   ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 3406  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 577                                                 NaN
# 1167  ['Security / Fire Alarm', 'Power Back-up', 'Fe...
#
#                                                  rating
# 2567                                                NaN
# 850   ['Green Area4 out of 5', 'Construction4 out of...
# 3406  ['Environment5 out of 5', 'Lifestyle4 out of 5...
# 577   ['Environment4 out of 5', 'Lifestyle4.5 out of...
# 1167  ['Green Area5 out of 5', 'Construction5 out of...
#
# [5 rows x 21 columns]

# %% [markdown]
# # **Drop Features**

# %%
# features to drop -> property_name, address, description, rating
df.drop(columns=['property_name', 'address', 'description', 'rating'],inplace=True)

# %%
df.sample(5)
# Out:
#      property_type             society      sector  price  price_per_sqft  \
# 2411         house         independent   sector 55   5.00         44444.0
# 2159         house         independent   sector 11   2.50         17857.0
# 3678          flat     eldeco accolade  sohna road   1.10          7549.0
# 952           flat  godrej nature plus   sector 33   1.50          9677.0
# 2731          flat     eldeco accolade  sohna road   0.95          6542.0
#
#         area                                       areaWithType  bedRoom  \
# 2411  1125.0  Plot area 125(104.52 sq.m.)Built Up area: 115 ...        9
# 2159  1400.0  Plot area 1400(130.06 sq.m.)Built Up area: 185...        5
# 3678  1457.0             Super Built up area 1457(135.36 sq.m.)        2
# 952   1550.0                Super Built up area 1550(144 sq.m.)        3
# 2731  1452.0  Super Built up area 1452(134.9 sq.m.)Carpet ar...        2
#
#       bathroom balcony     additionalRoom  floorNum facing  \
# 2411         9      3+             others       5.0   East
# 2159         4       3         store room       1.0   East
# 3678         2      3+  study room,others      17.0    NaN
# 952          3       3         study room       6.0   East
# 2731         2      3+         study room       6.0   East
#
#            agePossession                                    nearbyLocations  \
# 2411     0 to 1 Year Old  ['Sector metro station', 'Sector metro station...
# 2159        10+ Year Old  ['Rajiv Chowk Mosque', 'Hanuman Mandir', 'Hdfc...
# 3678     1 to 5 Year Old  ['Global City Centre', 'Sohna Road', 'Damdama ...
# 952   Under Construction  ['Signature Global Infinity Mall Sohna', 'Bads...
# 2731     0 to 1 Year Old  ['Global City Centre', 'Sohna Road', 'Damdama ...
#
#                                          furnishDetails  \
# 2411  ['14 Fan', '9 Geyser', '17 Light', '10 AC', '9...
# 2159                                                 []
# 3678  ['1 Water Purifier', '1 Exhaust Fan', '2 Geyse...
# 952   ['2 Wardrobe', '2 Fan', '3 Geyser', '5 Light',...
# 2731  ['2 Wardrobe', '1 Exhaust Fan', '14 Light', '1...
#
#                                                features
# 2411  ['Private Garden / Terrace', 'Maintenance Staf...
# 2159                                                NaN
# 3678                                ['Visitor Parking']
# 952   ['Feng Shui / Vaastu Compliant', 'Security / F...
# 2731                                                NaN

# %%
df.shape
# Out:
# (3803, 17)

# %% [markdown]
#  * **feature engineering required** -> areaWithType, additionalRoom, facing, agePossession, furnishDetails, features
#  * So we do Feature engineering in our Data so we export this datset as CSV

# %%
df.to_csv('gurgaon_properties_cleaned_v1.csv',index=False)
